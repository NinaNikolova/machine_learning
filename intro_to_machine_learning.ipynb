# %% [markdown]
# <a href="https://colab.research.google.com/github/NinaNikolova/machine_learning/blob/main/intro_to_machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import file from google drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/drive/My Drive/titanic.csv"
df = pd.read_csv(file_path)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.Age.value_counts(dropna=False)
# Out:
# Age
# NaN      177
# 24.00     30
# 22.00     27
# 18.00     26
# 28.00     25
#         ...
# 36.50      1
# 55.50      1
# 0.92       1
# 23.50      1
# 74.00      1
# Name: count, Length: 89, dtype: int64

# %%
df.Age.value_counts(dropna=False) / len(df) * 100
# Out:
# Age
# NaN      19.865320
# 24.00     3.367003
# 22.00     3.030303
# 18.00     2.918070
# 28.00     2.805836
#            ...
# 36.50     0.112233
# 55.50     0.112233
# 0.92      0.112233
# 23.50     0.112233
# 74.00     0.112233
# Name: count, Length: 89, dtype: float64

# %%
df.Fare.value_counts().hist(bins=20)
# Out:
# <Axes: >

# %%
df.Fare.sort_values()
# Out:
# 271      0.0000
# 597      0.0000
# 302      0.0000
# 633      0.0000
# 277      0.0000
#          ...
# 438    263.0000
# 341    263.0000
# 737    512.3292
# 258    512.3292
# 679    512.3292
# Name: Fare, Length: 891, dtype: float64

# %%
attribute = df.drop(columns = ["PassengerId","Survived", "Pclass", "Name", "Sex", "Age", "SibSp",
       "Parch", "Ticket" ])
attribute.Cabin.dropna()
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
#           ...
# 871            D35
# 872    B51 B53 B55
# 879            C50
# 887            B42
# 889           C148
# Name: Cabin, Length: 204, dtype: object

# %%
attribute.Cabin.isna()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %% [markdown]
# Scaling

# %%
df.Fare - df.Fare.mean() / df.Fare.std()
# Out:
# 0       6.601942
# 1      70.635242
# 2       7.276942
# 3      52.451942
# 4       7.401942
#          ...
# 886    12.351942
# 887    29.351942
# 888    22.801942
# 889    29.351942
# 890     7.101942
# Name: Fare, Length: 891, dtype: float64

# %%
pd.get_dummies(df[["Fare"]]).astype(int)
# Out:
#      Fare
# 0       7
# 1      71
# 2       7
# 3      53
# 4       8
# ..    ...
# 886    13
# 887    30
# 888    23
# 889    30
# 890     7
#
# [891 rows x 1 columns]
